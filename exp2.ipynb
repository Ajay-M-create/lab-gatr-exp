# %%
import torch
from lab_gatr import PointCloudPoolingScales, LaBGATr
import torch_geometric as pyg
from gatr.interface import embed_oriented_plane, extract_translation
import os
import numpy as np

# %%
def load_point_clouds(directory='./3d_point_cloud_dataset'):
    point_clouds = []
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            file_path = os.path.join(directory, filename)
            cloud_points = []

            with open(file_path, 'r') as f:
                for line in f:
                    # Skip lines that do not contain numeric values
                    try:
                        # Try to convert the line to a float, meaning it's a numeric line
                        point = list(map(float, line.split()))
                        if len(point) == 3:  # Ensure it's a 3D point
                            cloud_points.append(point)
                    except ValueError:
                        # Skip the line if it can't be converted to floats
                        continue

            # Convert the list of points to a numpy array and append to the dataset
            point_clouds.append(np.array(cloud_points))

    return point_clouds

point_clouds = load_point_clouds()
print(f"Loaded {len(point_clouds)} point clouds.")
# Out:
# Loaded 1500 point clouds.

# %%
def prepare_data_for_model(point_clouds):
    pos = []
    orientation = []
    scalar_feature = []
    
    for cloud in point_clouds:
        # Example: Assume that we use the first point as the position and normal as the orientation
        pos.append(cloud[0])  # First point as the position (this is just an example)
        orientation.append(np.random.rand(3))  # Random orientation (replace with real logic)
        scalar_feature.append(np.random.rand(1))  # Random scalar (replace with real data)

    pos = torch.tensor(np.array(pos), dtype=torch.float32)
    orientation = torch.tensor(np.array(orientation), dtype=torch.float32)
    scalar_feature = torch.tensor(np.array(scalar_feature), dtype=torch.float32)

    return pyg.data.Data(pos=pos, orientation=orientation, scalar_feature=scalar_feature)

# Prepare the data
data = prepare_data_for_model(point_clouds)
print(f"Data prepared with {data.pos.shape[0]} samples.")
# Out:
# Data prepared with 1500 samples.

# %%
class GeometricAlgebraInterface:
    num_input_channels = num_output_channels = 1
    num_input_scalars = num_output_scalars = 1

    @staticmethod
    @torch.no_grad()
    def embed(data):
        # Embed the point cloud into multivectors and scalars (your model-specific logic here)
        multivectors = embed_oriented_plane(normal=data.orientation, position=data.pos).view(-1, 1, 16)
        scalars = data.scalar_feature.view(-1, 1)
        return multivectors, scalars

    @staticmethod
    def dislodge(multivectors, scalars):
        return extract_translation(multivectors).squeeze()

# %%
model = LaBGATr(GeometricAlgebraInterface, d_model=8, num_blocks=10, num_attn_heads=4, use_class_token=False)

# Print the model architecture
print(model)


# 5. Load and preprocess point cloud data
point_clouds = load_point_clouds('./3d_point_cloud_dataset')
print(f"Loaded {len(point_clouds)} point clouds.")

# Prepare data for the model
data = prepare_data_for_model(point_clouds)
print(f"Data prepared with {data.pos.shape[0]} samples.")


# 6. Run the model with the prepared data
output = model(data)
print(f"Output shape: {output.shape}")


# 7. Surrogate regression task: Compute loss (Dummy target values for regression)
target = torch.rand_like(output)  # Replace with actual ground truth labels

# Compute the regression loss (e.g., Mean Squared Error)
loss_fn = torch.nn.MSELoss()
loss = loss_fn(output, target)
print(f"Regression Loss: {loss.item()}")
# Out:
# LaB-GATr (261761 parameters)
# LaBGATr(
#   (tokeniser): CrossAttentionTokeniser(
#     (point_cloud_pooling): PointCloudPooling()
#     (mlp): MLP(
#       (linear_layers): ModuleList(
#         (0): GeometricBilinear(
#           (linear_left): EquiLinear(
#             (s2mvs): Linear(in_features=2, out_features=4, bias=True)
#           )
#           (linear_right): EquiLinear(
#             (s2mvs): Linear(in_features=2, out_features=4, bias=True)
#           )
#           (linear_join_left): EquiLinear(
#             (s2mvs): Linear(in_features=2, out_features=4, bias=True)
#           )
#           (linear_join_right): EquiLinear(
#             (s2mvs): Linear(in_features=2, out_features=4, bias=True)
#           )
#           (linear_out): EquiLinear(
#             (s2mvs): Linear(in_features=2, out_features=8, bias=True)
#             (mvs2s): Linear(in_features=8, out_features=32, bias=True)
#             (s2s): Linear(in_features=2, out_features=32, bias=False)
#           )
#         )
#         (1): EquiLinear(
#           (s2mvs): Linear(in_features=32, out_features=8, bias=True)
#           (mvs2s): Linear(in_features=8, out_features=32, bias=True)
#           (s2s): Linear(in_features=32, out_features=32, bias=False)
#         )
#         (2): EquiLinear(
#           (s2mvs): Linear(in_features=32, out_features=1, bias=True)
#           (mvs2s): Linear(in_features=8, out_features=1, bias=True)
#           (s2s): Linear(in_features=32, out_features=1, bias=False)
#         )
#       )
#       (norm_layers): ModuleList(
#         (0): Identity()
#         (1): EquiLayerNorm()
#         (2): Identity()
#       )
#       (activations): ModuleList(
#         (0-1): 2 x ScalarGatedNonlinearity()
#         (2): Identity()
#       )
#       (dropout): Identity()
#     )
#     (cross_attention_hatchling): CrossAttentionHatchling(
#       (input_layer_source): EquiLinear(
#         (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#         (mvs2s): Linear(in_features=1, out_features=1, bias=True)
#         (s2s): Linear(in_features=1, out_features=1, bias=False)
#       )
#       (input_layer_target): EquiLinear(
#         (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#         (mvs2s): Linear(in_features=1, out_features=1, bias=True)
#         (s2s): Linear(in_features=1, out_features=1, bias=False)
#       )
#       (block): CrossAttentionBlock(
#         (norm): EquiLayerNorm()
#         (attention): CrossAttention(
#           (q_linear): EquiLinear(
#             (s2mvs): Linear(in_features=1, out_features=16, bias=True)
#             (mvs2s): Linear(in_features=8, out_features=16, bias=True)
#             (s2s): Linear(in_features=1, out_features=16, bias=False)
#           )
#           (k_linear): EquiLinear(
#             (s2mvs): Linear(in_features=1, out_features=4, bias=True)
#             (mvs2s): Linear(in_features=8, out_features=4, bias=True)
#             (s2s): Linear(in_features=1, out_features=4, bias=False)
#           )
#           (v_linear): EquiLinear(
#             (s2mvs): Linear(in_features=1, out_features=4, bias=True)
#             (mvs2s): Linear(in_features=8, out_features=4, bias=True)
#             (s2s): Linear(in_features=1, out_features=4, bias=False)
#           )
#           (out_linear): EquiLinear(
#             (s2mvs): Linear(in_features=16, out_features=8, bias=True)
#             (mvs2s): Linear(in_features=16, out_features=1, bias=True)
#             (s2s): Linear(in_features=16, out_features=1, bias=False)
#           )
#           (attention): GeometricAttention()
#         )
#         (mlp): GeoMLP(
#           (layers): ModuleList(
#             (0): GeometricBilinear(
#               (linear_left): EquiLinear(
#                 (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#               )
#               (linear_right): EquiLinear(
#                 (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#               )
#               (linear_join_left): EquiLinear(
#                 (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#               )
#               (linear_join_right): EquiLinear(
#                 (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#               )
#               (linear_out): EquiLinear(
#                 (s2mvs): Linear(in_features=1, out_features=16, bias=True)
#                 (mvs2s): Linear(in_features=16, out_features=2, bias=True)
#                 (s2s): Linear(in_features=1, out_features=2, bias=False)
#               )
#             )
#             (1): ScalarGatedNonlinearity()
#             (2): EquiLinear(
#               (s2mvs): Linear(in_features=2, out_features=8, bias=True)
#               (mvs2s): Linear(in_features=16, out_features=1, bias=True)
#               (s2s): Linear(in_features=2, out_features=1, bias=False)
#             )
#           )
#         )
#       )
#       (output_layer): EquiLinear(
#         (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#         (mvs2s): Linear(in_features=8, out_features=1, bias=True)
#         (s2s): Linear(in_features=1, out_features=1, bias=False)
#       )
#     )
#   )
#   (gatr): GATr(
#     (linear_in): EquiLinear(
#       (s2mvs): Linear(in_features=1, out_features=8, bias=True)
#       (mvs2s): Linear(in_features=8, out_features=32, bias=True)
#       (s2s): Linear(in_features=1, out_features=32, bias=False)
#     )
#     (blocks): ModuleList(
#       (0-9): 10 x GATrBlock(
#         (norm): EquiLayerNorm()
#         (attention): SelfAttention(
#           (qkv_module): MultiQueryQKVModule(
#             (q_linear): EquiLinear(
#               (s2mvs): Linear(in_features=32, out_features=16, bias=True)
#               (mvs2s): Linear(in_features=8, out_features=64, bias=True)
#               (s2s): Linear(in_features=32, out_features=64, bias=False)
#             )
#             (k_linear): EquiLinear(
#               (s2mvs): Linear(in_features=32, out_features=4, bias=True)
#               (mvs2s): Linear(in_features=8, out_features=16, bias=True)
#               (s2s): Linear(in_features=32, out_features=16, bias=False)
#             )
#             (v_linear): EquiLinear(
#               (s2mvs): Linear(in_features=32, out_features=4, bias=True)
#               (mvs2s): Linear(in_features=8, out_features=16, bias=True)
#               (s2s): Linear(in_features=32, out_features=16, bias=False)
#             )
#           )
#           (out_linear): EquiLinear(
#             (s2mvs): Linear(in_features=64, out_features=8, bias=True)
#             (mvs2s): Linear(in_features=16, out_features=32, bias=True)
#             (s2s): Linear(in_features=64, out_features=32, bias=False)
#           )
#           (pos_encoding): Identity()
#           (attention): GeometricAttention()
#         )
#         (mlp): GeoMLP(
#           (layers): ModuleList(
#             (0): GeometricBilinear(
#               (linear_left): EquiLinear(
#                 (s2mvs): Linear(in_features=32, out_features=8, bias=True)
#               )
#               (linear_right): EquiLinear(
#                 (s2mvs): Linear(in_features=32, out_features=8, bias=True)
#               )
#               (linear_join_left): EquiLinear(
#                 (s2mvs): Linear(in_features=32, out_features=8, bias=True)
#               )
#               (linear_join_right): EquiLinear(
#                 (s2mvs): Linear(in_features=32, out_features=8, bias=True)
#               )
#               (linear_out): EquiLinear(
#                 (s2mvs): Linear(in_features=32, out_features=16, bias=True)
#                 (mvs2s): Linear(in_features=16, out_features=64, bias=True)
#                 (s2s): Linear(in_features=32, out_features=64, bias=False)
#               )
#             )
#             (1): ScalarGatedNonlinearity()
#             (2): EquiLinear(
#               (s2mvs): Linear(in_features=64, out_features=8, bias=True)
#               (mvs2s): Linear(in_features=16, out_features=32, bias=True)
#               (s2s): Linear(in_features=64, out_features=32, bias=False)
#             )
#           )
#         )
#       )
#     )
#     (linear_out): EquiLinear(
#       (s2mvs): Linear(in_features=32, out_features=8, bias=True)
#       (mvs2s): Linear(in_features=8, out_features=1, bias=True)
#       (s2s): Linear(in_features=32, out_features=1, bias=False)
#     )
#   )
# )
# Loaded 1500 point clouds.
# Data prepared with 1500 samples.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 17
#      13 print(f"Data prepared with {data.pos.shape[0]} samples.")
#      16 # 6. Run the model with the prepared data
# ---> 17 output = model(data)
#      18 print(f"Output shape: {output.shape}")
#      21 # 7. Surrogate regression task: Compute loss (Dummy target values for regression)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/lab-gatr/lab_gatr/models/lab_gatr.py:71, in LaBGATr.forward(self, data)
#      70 def forward(self, data: Data) -> torch.Tensor:
# ---> 71     multivectors, scalars, reference_multivector = self.tokeniser(data)
#      73     multivectors, scalars = self.gatr(
#      74         multivectors,
#      75         scalars=scalars,
#      76         attention_mask=get_attn_mask(data.batch[data.scale0_sampling_index] if data.batch is not None else data.batch),
#      77         join_reference=reference_multivector
#      78     )
#      80     return self.tokeniser.lift(multivectors, scalars)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/lab-gatr/lab_gatr/models/lab_gatr.py:324, in CrossAttentionTokeniser.forward(self, data)
#     316 def forward(self, data: Data) -> tuple:
#     317     multivectors, scalars = self.geometric_algebra_interface.embed(data)
#     319     self.cache = {
#     320         'multivectors': multivectors,
#     321         'scalars': scalars,
#     322         'data': data,
#     323         'reference_multivector': self.construct_reference_multivector(multivectors, data.batch),
# --> 324         'pos': data.pos[data.scale0_sampling_index]
#     325     }
#     327     attn_mask = get_attn_mask(
#     328         target_batch=data.batch[data.scale0_sampling_index] if data.batch is not None else data.batch,
#     329         source_batch=data.batch
#     330     )
#     332     reference_multivector = self.cache['reference_multivector'][data.scale0_sampling_index]
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch_geometric/data/data.py:561, in Data.__getattr__(self, key)
#     555 if '_store' not in self.__dict__:
#     556     raise RuntimeError(
#     557         "The 'data' object was created by an older version of PyG. "
#     558         "If this error occurred while loading an already existing "
#     559         "dataset, remove the 'processed/' directory in the dataset's "
#     560         "root folder and try again.")
# --> 561 return getattr(self._store, key)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch_geometric/data/storage.py:96, in BaseStorage.__getattr__(self, key)
#      94     return self[key]
#      95 except KeyError:
# ---> 96     raise AttributeError(
#      97         f"'{self.__class__.__name__}' object has no attribute '{key}'"
#      98     ) from None
#
# AttributeError: 'GlobalStorage' object has no attribute 'scale0_sampling_index'

# %%
# Forward pass through the model
output = model(data)
print(f"Output shape: {output.shape}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Forward pass through the model
# ----> 2 output = model(data)
#       3 print(f"Output shape: {output.shape}")
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/lab-gatr/lab_gatr/models/lab_gatr.py:71, in LaBGATr.forward(self, data)
#      70 def forward(self, data: Data) -> torch.Tensor:
# ---> 71     multivectors, scalars, reference_multivector = self.tokeniser(data)
#      73     multivectors, scalars = self.gatr(
#      74         multivectors,
#      75         scalars=scalars,
#      76         attention_mask=get_attn_mask(data.batch[data.scale0_sampling_index] if data.batch is not None else data.batch),
#      77         join_reference=reference_multivector
#      78     )
#      80     return self.tokeniser.lift(multivectors, scalars)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/lab-gatr/lab_gatr/models/lab_gatr.py:324, in CrossAttentionTokeniser.forward(self, data)
#     316 def forward(self, data: Data) -> tuple:
#     317     multivectors, scalars = self.geometric_algebra_interface.embed(data)
#     319     self.cache = {
#     320         'multivectors': multivectors,
#     321         'scalars': scalars,
#     322         'data': data,
#     323         'reference_multivector': self.construct_reference_multivector(multivectors, data.batch),
# --> 324         'pos': data.pos[data.scale0_sampling_index]
#     325     }
#     327     attn_mask = get_attn_mask(
#     328         target_batch=data.batch[data.scale0_sampling_index] if data.batch is not None else data.batch,
#     329         source_batch=data.batch
#     330     )
#     332     reference_multivector = self.cache['reference_multivector'][data.scale0_sampling_index]
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch_geometric/data/data.py:561, in Data.__getattr__(self, key)
#     555 if '_store' not in self.__dict__:
#     556     raise RuntimeError(
#     557         "The 'data' object was created by an older version of PyG. "
#     558         "If this error occurred while loading an already existing "
#     559         "dataset, remove the 'processed/' directory in the dataset's "
#     560         "root folder and try again.")
# --> 561 return getattr(self._store, key)
#
# File ~/anaconda3/envs/anatomygen_gatr/lib/python3.10/site-packages/torch_geometric/data/storage.py:96, in BaseStorage.__getattr__(self, key)
#      94     return self[key]
#      95 except KeyError:
# ---> 96     raise AttributeError(
#      97         f"'{self.__class__.__name__}' object has no attribute '{key}'"
#      98     ) from None
#
# AttributeError: 'GlobalStorage' object has no attribute 'scale0_sampling_index'

# %%
# Dummy target values for regression (replace with actual ground truth)
target = torch.rand_like(output)

# Compute a regression loss (e.g., Mean Squared Error)
loss_fn = torch.nn.MSELoss()
loss = loss_fn(output, target)
print(f"Regression Loss: {loss.item()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Dummy target values for regression (replace with actual ground truth)
# ----> 2 target = torch.rand_like(output)
#       4 # Compute a regression loss (e.g., Mean Squared Error)
#       5 loss_fn = torch.nn.MSELoss()
#
# NameError: name 'output' is not defined
